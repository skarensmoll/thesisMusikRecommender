# %%
# Out:
# 3738

# %%
SongsInfo[0]
# Out:
# {'id': '3quIqeqcnQaiyM8X7kK7Wm',
#  'name': 'For Narmer (From "Warframe")',
#  'artist': 'Keith Power',
#  'ytlink': 'https://www.youtube.com/watch?v=xTaCl9wWt4I',
#  'mainlink': 'https://open.spotify.com/track/3quIqeqcnQaiyM8X7kK7Wm'}

# %%
paths = []
for i, song in enumerate(SongsInfo):
    paths.append('musicYoutube/' + song['id'] + '.mp3')

# %%
paths
# Out:
# ['music/3quIqeqcnQaiyM8X7kK7Wm.mp3',
#  'music/7nq8DgNdgYGihJrZYB221C.mp3',
#  'music/54T6BKSPCO5NcFXHzrSb9W.mp3',
#  'music/2CVf3ApXLk1cXQ2B6Z9ZlS.mp3',
#  'music/4hbO390vbRE8dNVx3oCwaF.mp3',
#  'music/3kxEAkXVz45ysdavxSCuid.mp3',
#  'music/3I0AM51TcmZBTfVi0gDFFU.mp3',
#  'music/1cp7pENCkTI63S6TIjFyVN.mp3',
#  'music/4UicwYFLdxrFl2gLVvlsiF.mp3',
#  'music/3PTD2eturmZsdedW6reT1p.mp3',
#  'music/6X1NTiQlYqVr94gB7T2GFj.mp3',
#  'music/4IVyX0UJzGyUk0MLiz1jVJ.mp3',
#  'music/5S11x5kTJN5SLSY0RDDFMI.mp3',
#  'music/2c3iovaZqJhIhXnV28dand.mp3',
#  'music/2hHAjvHx7gZL3zSPHYMEwn.mp3',
#  'music/3tZm76otWH20xzJC7icHCk.mp3',
#  'music/5zFglKYiknIxks8geR8rcL.mp3',
#  'music/4uX1pkSuSidzJxT4eWL7x1.mp3',
#  'music/54WpJSyO81dpA40MKJHd0C.mp3',
#  'music/1G5rzVAFlgMqG4gaRujcaA.mp3',
#  'music/6PyFYTEo8X3inQ4hQvA8md.mp3',
#  'music/6FDKYM0lBf6zqrg8cFokPd.mp3',
#  'music/0r7CVbZTWZgbTCYdfa2P31.mp3',
#  'music/06ylybDHRyv6wEpjBc9TKn.mp3',
#  'music/6V1bu6o1Yo5ZXnsCJU8Ovk.mp3',
# ...
