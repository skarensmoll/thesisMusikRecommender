# %%
import pandas as pd
df = pd.read_csv('./data/experiments-analysis/ranks_covers_0100.csv')
df = df.iloc[:, 1:]

# %%
df
# Out:
#     id_chord        id_spotify_track  year  \
# 0    6001027  75JFxkI2RXiU7L9VXzMkle  2002
# 1     180849  3jButwtJMLx3Ub61BfRiHh  2022
# 2    5000008  68iMdxXn1timrxURm9dR8C  2012
# 3    5000023  6f46TyGZm5oeKIP54PLvql  2014
# 4    5000011  5FoM2ZWwhgTxHFFh2stUw6  2022
# 5    1686718  2LbHYfTYW6TipHInIjqdaQ  2015
# 6    5000013  2LbHYfTYW6TipHInIjqdaQ  2015
# 7    5000017  34dnNAUoIPcwnK0RtVMBWZ  2013
# 8    5000001  025vpSSyndhVZezl8rUF6L  2018
# 9    5000007  6TyaYGQKCnRLVTOQlXvYAA  2019
# 10   5000018  49Nzxf1LskunwmZ6EyWUew  2018
# 11   5000012  7tn1tcxenMwDXrYTOjS3z1  2017
# 12   5000020  66Z3LdLjtwfIdHFF0wZa5B  2016
# 13   5000019  49ilSrZNQcle6PYw8rtvzM  2021
#
#                                           artist  \
# 0                                       Coldplay
# 1                                       Coldplay
# 2                                      Glee Cast
# 3                                      Glee Cast
# 4                                  Savanna Leigh
# ...

# %%
tb = pd.read_csv('./data/experiments-analysis/ranks_covers_0200.csv')
tb = tb.iloc[:, 1:]

# %%
tb['year'] = 0
tb['artist'] = ''

# %%
tb
# Out:
#     id_chord        id_spotify_track           name release_date  percentage  \
# 0     180849  3jButwtJMLx3Ub61BfRiHh  the scientist   2022-06-03     100.000
# 1    5000007  6TyaYGQKCnRLVTOQlXvYAA            NaN          NaN      99.762
# 2    5000019  49ilSrZNQcle6PYw8rtvzM            NaN          NaN      99.737
# 3    5000018  49Nzxf1LskunwmZ6EyWUew            NaN          NaN      99.733
# 4    5000020  66Z3LdLjtwfIdHFF0wZa5B            NaN          NaN      99.699
# 5    6001027  75JFxkI2RXiU7L9VXzMkle            NaN          NaN      99.692
# 6    5000008  68iMdxXn1timrxURm9dR8C            NaN          NaN      99.689
# 7    1686718  2LbHYfTYW6TipHInIjqdaQ  the scientist   2015-04-28      99.686
# 8    5000011  5FoM2ZWwhgTxHFFh2stUw6            NaN          NaN      99.675
# 9    5000012  7tn1tcxenMwDXrYTOjS3z1            NaN          NaN      99.673
# 10   5000017  34dnNAUoIPcwnK0RtVMBWZ            NaN          NaN      99.673
# ...

# %%
df = df.append(tb)

# %%
df
# Out:
#     id_chord        id_spotify_track  year         artist  \
# 0    6001027  75JFxkI2RXiU7L9VXzMkle  2002       Coldplay
# 1     180849  3jButwtJMLx3Ub61BfRiHh  2022       Coldplay
# 2    5000008  68iMdxXn1timrxURm9dR8C  2012      Glee Cast
# 3    5000023  6f46TyGZm5oeKIP54PLvql  2014      Glee Cast
# 4    5000011  5FoM2ZWwhgTxHFFh2stUw6  2022  Savanna Leigh
# ..       ...                     ...   ...            ...
# 9    5000012  7tn1tcxenMwDXrYTOjS3z1     0
# 10   5000017  34dnNAUoIPcwnK0RtVMBWZ     0
# 11   5000013  2LbHYfTYW6TipHInIjqdaQ     0
# 12   5000001  025vpSSyndhVZezl8rUF6L     0
# 13   5000023  6f46TyGZm5oeKIP54PLvql     0
#
#                                  name release_date  percentage      rank  \
# 0   The Scientist (Glee Cast Version)          NaN     100.000  0.000000
# 1   The Scientist (Glee Cast Version)       6/3/22     100.000  0.000000
# 2   The Scientist (Glee Cast Version)          NaN      98.742  1.257849
# ...

# %%
import os
os.makedirs('./data', exist_ok=True)  
df.to_csv('./data/experiments-analysis/coldplayResults.csv')
