# %%
import pandas as pd
df = pd.read_csv('./data/unified/ranks_0822_cleaned.csv')

# %%
df.head(20)
# Out:
#     experiment_id  best_score_cover  best_score_cover_id  \
# 0             100                93              5000008
# 1             102               174              5000008
# 2             103                91              5000008
# 3             200                28              5000007
# 4             202                21              5000018
# 5             203                39              5000007
# 6             300                33              5000019
# 7             400                16              5000019
# 8             500                16              5000019
# 9             502                26              5000013
# 10            600                21              5000019
# 11            700                 4              5000019
# 12            702                 8              5000017
# 13            703                22              5000017
# 14            704                 9              5000017
# ...
