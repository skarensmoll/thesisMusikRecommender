# %%
import pandas as pd
import os

# %%
= pd.read_csv('./data/FinalMergedCleanChordsTracks.csv')
FinalMergedCleanChordsTracks.drop_duplicates('id_spotify_track',inplace=True)
FinalMergedCleanChordsTracks = FinalMergedCleanChordsTracks.iloc[:,1:]
FinalMergedCleanChordsTracks
# Out:
#       id_chord        id_spotify_track  id_track
# 0      5000001  025vpSSyndhVZezl8rUF6L   8000001
# 1      5000007  6TyaYGQKCnRLVTOQlXvYAA   8000007
# 2      5000008  68iMdxXn1timrxURm9dR8C   8000008
# 3      5000023  6f46TyGZm5oeKIP54PLvql   8000023
# 4      5000017  34dnNAUoIPcwnK0RtVMBWZ   8000017
# ...        ...                     ...       ...
# 5845     79685  7zMUCLm1TN9o9JlLISztxO      1715
# 5846     39828  7zmVAVcT1oho7iWJGpApkE       920
# 5847    957714  7znAjItIP7xKKhyFzF5W1B      6489
# 5848   1172824  7zuwaenG5AF0vG7o7kMduX      7887
# 5849    930394  7zVfEu1dEvRw4EkWoqrBkx      6345
#
# [5850 rows x 3 columns]

# %%
coldplaySongsSpotifyFeatures = pd.read_csv('./data/coldplaySongsSpotifyFeatures.csv')
coldplaySongsSpotifyFeatures.drop_duplicates('id_spotify_track',inplace=True)
coldplaySongsSpotifyFeatures = coldplaySongsSpotifyFeatures.iloc[:,1:]
coldplaySongsSpotifyFeatures = coldplaySongsSpotifyFeatures[['id_chord', 'id_spotify_track', 'id_track', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
       'time_signature', 'name', 'popularity', 'album_name', 'release_date']]
coldplaySongsSpotifyFeatures
# Out:
#     id_chord        id_spotify_track  \
# 0    5000001  025vpSSyndhVZezl8rUF6L
# 1    5000007  6TyaYGQKCnRLVTOQlXvYAA
# 2    5000008  68iMdxXn1timrxURm9dR8C
# 3    5000023  6f46TyGZm5oeKIP54PLvql
# 4    5000017  34dnNAUoIPcwnK0RtVMBWZ
# 5    5000019  49ilSrZNQcle6PYw8rtvzM
# 6    5000020  66Z3LdLjtwfIdHFF0wZa5B
# 7    5000013  2LbHYfTYW6TipHInIjqdaQ
# 8    5000018  49Nzxf1LskunwmZ6EyWUew
# 9    5000011  5FoM2ZWwhgTxHFFh2stUw6
# 10   5000012  7tn1tcxenMwDXrYTOjS3z1
#
#                                              id_track  danceability  energy  \
# 0   Coldplay - The Scientist (Cello & Piano) - Bro...         0.255   0.343
# 1   GABRIELLA - Coldplay - The Scientist (Cover) (...         0.273   0.205
# 2   GLEE - The Scientist (Full Performance) (Offic...         0.506   0.481
# 3       gleechapversionthescientist-converted.mp3.csv         0.495   0.489
# 4   The Scientist - Coldplay Cover (ft. Kina Grann...         0.453   0.295
# ...

# %%
BatchSongsSpotifyFeatures = pd.read_csv('./data/BatchSongsSpotifyFeatures.csv')
BatchSongsSpotifyFeatures.drop_duplicates('id_spotify_track',inplace=True)
BatchSongsSpotifyFeatures = BatchSongsSpotifyFeatures.iloc[:,1:]
BatchSongsSpotifyFeatures = BatchSongsSpotifyFeatures[['id_chord', 'id_spotify_track', 'id_track', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
       'time_signature', 'name', 'popularity', 'album_name', 'release_date']]
BatchSongsSpotifyFeatures
# Out:
#       id_chord        id_spotify_track  id_track  danceability  energy  key  \
# 0      6000001  3quIqeqcnQaiyM8X7kK7Wm       NaN        0.3430   0.267    1
# 1      6000002  7nq8DgNdgYGihJrZYB221C       NaN        0.7160   0.808    7
# 2      6000003  54T6BKSPCO5NcFXHzrSb9W       NaN        0.0994   0.554    9
# 3      6000004  2CVf3ApXLk1cXQ2B6Z9ZlS       NaN        0.1710   0.508    1
# 4      6000005  4hbO390vbRE8dNVx3oCwaF       NaN        0.5920   0.836    4
# ...        ...                     ...       ...           ...     ...  ...
# 2492   6002496  6si71supnBUhddjR2FJc2L       NaN        0.5090   0.537    5
# 2493   6002497  3yUcJwYu7fXAfqMj9krY6l       NaN        0.7250   0.583    1
# 2494   6002498  4VrWlk8IQxevMvERoX08iC       NaN        0.3990   0.787    1
# 2495   6002499  2rW17Yz3pncp87DU20jBZ7       NaN        0.3760   0.435    2
# 2496   6002500  4058DPUoC7sLPQ05pr3e4C       NaN        0.7340   0.663   10
#
# ...

# %%
mergeSpotifyFeatures = pd.concat([coldplaySongsSpotifyFeatures, BatchSongsSpotifyFeatures])
mergeSpotifyFeatures.drop_duplicates('id_spotify_track', inplace=True)
mergeSpotifyFeatures.drop(columns=['id_track'], inplace=True)
toMergeFinalMergedCleanChordsTracks = FinalMergedCleanChordsTracks[['id_spotify_track','id_track']]
mergeSpotifyFeatures = pd.merge(mergeSpotifyFeatures, toMergeFinalMergedCleanChordsTracks,on='id_spotify_track')
mergeSpotifyFeatures
# Out:
#       id_chord        id_spotify_track  danceability  energy  key  loudness  \
# 0      5000001  025vpSSyndhVZezl8rUF6L         0.255   0.343    5    -8.117
# 1      5000007  6TyaYGQKCnRLVTOQlXvYAA         0.273   0.205    4   -11.893
# 2      5000008  68iMdxXn1timrxURm9dR8C         0.506   0.481    2    -6.098
# 3      5000023  6f46TyGZm5oeKIP54PLvql         0.495   0.489    2    -6.083
# 4      5000017  34dnNAUoIPcwnK0RtVMBWZ         0.453   0.295    7   -12.881
# ...        ...                     ...           ...     ...  ...       ...
# 2503   6002496  6si71supnBUhddjR2FJc2L         0.509   0.537    5    -6.834
# 2504   6002497  3yUcJwYu7fXAfqMj9krY6l         0.725   0.583    1    -9.942
# 2505   6002498  4VrWlk8IQxevMvERoX08iC         0.399   0.787    1    -2.880
# 2506   6002499  2rW17Yz3pncp87DU20jBZ7         0.376   0.435    2    -7.584
# 2507   6002500  4058DPUoC7sLPQ05pr3e4C         0.734   0.663   10    -6.279
#
# ...

# %%
spotify_tracks = pd.read_csv('./data/spotify_tracks.csv')
#spotify_tracks.drop_duplicates('id_spotify_track',inplace=True)
spotify_tracks
# Out:
#           id              id_spotify                                name  \
# 0          1  2ap1hCe7wyOWkMJsnIn0V1      beer drinkers and hell raisers
# 1          2  2ap1hCe7wyOWkMJsnIn0V1      beer drinkers and hell raisers
# 2          3  4fzVO8BpWnUZBibQDN5Fju      beer drinkers and hell raisers
# 3          4  6mVFZi8EogqU6xz7eDAe1m      beer drinkers and hell raisers
# 4          5  2nekCvC9XRXQckWNnkIp2l                        harvest moon
# ...      ...                     ...                                 ...
# 11218  11219  7nm7JfzJtp63Y2S8xnru52  encanto - we dont talk about bruno
# 11219  11220  2mAOInj9BcKPkDzfomh10A  encanto - we dont talk about bruno
# 11220  11221  4LRPiXqCikLlN15c3yImP7                           as it was
# 11221  11222  4Dvkj6JhhA12EX05fT7y2e                           as it was
# 11222  11223  5h4vM1Wf80N2JpRFC9XATM                           as it was
#
#        popularity                                         album_name  \
# ...

# %%
finalmergcechordsspotify = pd.concat([chords_spotify_df, mergeSpotifyFeatures])
finalmergcechordsspotify.reset_index(inplace=True)
finalmergcechordsspotify = finalmergcechordsspotify.iloc[:,1:]
os.makedirs('./data', exist_ok=True)  
finalmergcechordsspotify.to_csv('./data/FinalMergedChordsSpotify.csv')
finalmergcechordsspotify
# Out:
#       id_chord        id_spotify_track  id_track  danceability  energy  key  \
# 0       202646  003vvx7Niy0yvhvHt4a68B      3034         0.352   0.911    1
# 1      1234782  006wINkRivz0PS6qANjCxY      8279         0.588   0.866    9
# 2       877151  0087fDVeNhuyMtST91RMjv      4159         0.335   0.571   11
# 3      1425968  009ImBOrIUlWgla8U05RAC      8606         0.432   0.725    7
# 4       808812  00hVU6kDP67JHurfwG2dtq      5384         0.645   0.417    4
# ...        ...                     ...       ...           ...     ...  ...
# 5987   6002496  6si71supnBUhddjR2FJc2L   9002496         0.509   0.537    5
# 5988   6002497  3yUcJwYu7fXAfqMj9krY6l   9002497         0.725   0.583    1
# 5989   6002498  4VrWlk8IQxevMvERoX08iC   9002498         0.399   0.787    1
# 5990   6002499  2rW17Yz3pncp87DU20jBZ7   9002499         0.376   0.435    2
# 5991   6002500  4058DPUoC7sLPQ05pr3e4C   9002500         0.734   0.663   10
#
# ...

# %%
finalspotifyaudiofeatures = finalmergcechordsspotify[['id_spotify_track','danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo','duration_ms','time_signature']]
finalspotifyaudiofeatures.rename(columns={'id_spotify_track': 'id_track'}, inplace=True)
os.makedirs('./data', exist_ok=True)  
finalspotifyaudiofeatures.to_csv('./data/FinalMergedSpotifyAudioFeatures.csv')
finalspotifyaudiofeatures
# Out:
# C:\Users\fjorg\AppData\Local\Temp\ipykernel_13780\46648164.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finalspotifyaudiofeatures.rename(columns={'id_spotify_track': 'id_track'}, inplace=True)
#                     id_track  danceability  energy  key  loudness  mode  \
# 0     003vvx7Niy0yvhvHt4a68B         0.352   0.911    1    -5.230     1
# 1     006wINkRivz0PS6qANjCxY         0.588   0.866    9    -4.715     1
# 2     0087fDVeNhuyMtST91RMjv         0.335   0.571   11    -4.711     1
# 3     009ImBOrIUlWgla8U05RAC         0.432   0.725    7    -4.862     1
# 4     00hVU6kDP67JHurfwG2dtq         0.645   0.417    4    -7.022     1
# ...                      ...           ...     ...  ...       ...   ...
# 5987  6si71supnBUhddjR2FJc2L         0.509   0.537    5    -6.834     1
# ...
