# %%
import sqlite3
import re
import json
import pandas as pd
import time
from bs4 import BeautifulSoup
from requests import get
from requests.exceptions import RequestException
from contextlib import closing

# %%
def simple_get(url):
    """
    Source: https://realpython.com/python-web-scraping-practical-introduction/
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Source: https://realpython.com/python-web-scraping-practical-introduction/
    Returns true if the response seems to be HTML, false otherwise
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    Source: https://realpython.com/python-web-scraping-practical-introduction/
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

def parse_data_content_from_url(url, max_retries=5):
    """
    This function parses the content on the given URL webpage and grabs the "data-content" 
    from the <div class='js-store'> tag. The data stored in this object includes all content 
    hosted on the webpage.
    """
    html = ''
    soup = ''
    attempt_num = 1
    while (html == '' or soup == '') and attempt_num < max_retries:
        try:
            print('Attempting to reach link: {}'.format(url))
            html = simple_get(url)
            soup = BeautifulSoup(html, 'html.parser')
            data_content = json.loads(soup.find("div", {'class':'js-store'})['data-content'])
            print('Succesfully loaded <div data-content>')
            return(data_content)
        except:
            attempt_num+=1
            print('Connection refused on server for link: {}'.format(url))
            print('Retrying for attempt {0}/{1} in 5 seconds'.format(attempt_num, max_retries))
            time.sleep(5)
            continue        
            
            
def parse_chords_from_url(url):
    """
    Scrapes and returns the sequences of 
    chords as a list as well as the fret number
    to place a capo. 
    """

    data = parse_data_content_from_url(url)

    chords = data['store']['page']['data']['tab_view']['wiki_tab']['content']
    
    # Matching groups (open tag)(chord pitch)(base note {0 or 1})(chord type)(base note {0 or 1})(closing tag)
    pattern = "(\[ch\])([A-G]+)(\/[A-G]*[b#])*([(?m)|(?m\d)|(?b\d)|(?#\d)|(?maj\d)|(?add\d)|(?sus\d)|(?aug)|(?aug\d)|(?dim)|(?dim\d)]*)(\/[A-G]*[b#])*(\[\/ch\])"
    prog = re.compile(pattern)
    result = prog.findall(chords)
    
    cleaned_res = result
    for i in range(len(result)):
        # Grabbing groups (chord pitch)(base note)(chord type)(base note)
        cleaned_res[i] = result[i][1] + result[i][2] + result[i][3] + result[i][4]
       
    # Grabbing Capo info
    capo = 0
    try:
        capo = data['store']['page']['data']['tab_view']['meta']['capo']
    except:
        capo = 0
        
    return(cleaned_res, capo)
            
def get_metadata_from_top_page(url):
    data_content = parse_data_content_from_url(url)
    tabs = data_content['store']['page']['data']['data']['tabs']
    hits = data_content['store']['page']['data']['data']['hits']
    
    return(tabs, hits)    

def get_multiple_pages(url, n):
    """
    Creates functionality to scrape multiple
    pages up to n
    """
    page_suffix = "&page="
    tabs_list = []
    hits_list = []
    
    for i in range(n):
        cur_tabs, cur_hits = get_metadata_from_top_page(url + page_suffix + str(i+1))
        
        tabs_list += cur_tabs
        hits_list += cur_hits
        
    return(tabs_list, hits_list)

def parse_tab_fields(tab_obj, hit_obj):
    tab_url = tab_obj['tab_url']
    chords, capo = parse_chords_from_url(tab_url)
    tab_dict = {
        'tab_id': int(tab_obj['id']),
        'song_name': re.sub("'", "", tab_obj['song_name']),
        'artist': re.sub("'", "", tab_obj['artist_name']),
        'tonality': tab_obj['tonality_name'],
        'votes': int(tab_obj['votes']),
        'rating': float(tab_obj['rating']),
        'is_acoustic': int(tab_obj['recording']['is_acoustic']),
        'tab_url': tab_obj['tab_url'],
        'artist_url': tab_obj['artist_url'],
        'hit_id': int(hit_obj['id']),
        'hit_num': int(hit_obj['hits']),
        'chords': ','.join(chords),
        'capo': capo
    }
    return tab_dict

def create_sqlite_connector(db='UltimateGuitarTabs.db'):
    con = sqlite3.connect('./{}'.format(db))
    cur = con.cursor()
    return(con, cur)

def drop_tables_if_exists(con, cur):
    delete_tabs = "DROP TABLE IF EXISTS Tab_Data;"
    cur.execute(delete_tabs)
    con.commit()
    
    delete_artists = "DROP TABLE IF EXISTS Artists;"
    cur.execute(delete_artists)
    con.commit()
    
    delete_hits = "DROP TABLE IF EXISTS Hits;"
    cur.execute(delete_hits)
    con.commit()
    
    delete_chords = "DROP TABLE IF EXISTS Chords;"
    cur.execute(delete_chords)
    con.commit()
    
def create_tables(con, cur):
    create_tabs = """
        CREATE TABLE Tab_Data (
            id integer primary key,
            song text,
            artist text,
            is_acoustic integer,
            tab_url text
        )"""
    cur.execute(create_tabs)
    con.commit()    

    create_artists = """
        CREATE TABLE Artists (
            name text,
            url text
        )"""
    cur.execute(create_artists)
    con.commit()


    create_hits = """
        CREATE TABLE Hits (
            id integer primary key, 
            num_hits integer, 
            votes integer,
            rating float
        )"""
    cur.execute(create_hits)
    con.commit()    

    create_chords = """
        CREATE TABLE Chords (
        id integer primary key,
        song text,
        artist text,
        tonality text,
        capo integer,
        chords text
        )"""
    cur.execute(create_chords)  
    con.commit()
    
def insert_data(tab_dict, con, cur):
    try: 
        sql_tab = "insert into Tab_Data (id,song,artist,is_acoustic,tab_url) \
        VALUES ('%d','%s','%s','%d','%s')" % \
            (tab_dict['tab_id'], tab_dict['song_name'], tab_dict['artist'],
             tab_dict['is_acoustic'], tab_dict['tab_url'])
        cur.execute(sql_tab)
        con.commit()

    except:
        print('Unable to insert into Tab_Data')
        print(tab_dict)        
        
    try:
        sql_artist = "insert into Artists (name, url) VALUES ('%s','%s')" %\
            (tab_dict['artist'], tab_dict['artist_url'])
        cur.execute(sql_artist)
        con.commit()
    except:
        print('Unable to insert into Artists')
        print(tab_dict)
        

    try:
        sql_hit = "insert into Hits (id, num_hits, votes, rating) VALUES ('%d','%d','%d','%.8f')" %\
            (tab_dict['tab_id'], tab_dict['hit_num'],
             tab_dict['votes'], tab_dict['rating'])
        cur.execute(sql_hit)
        con.commit()
        
    except:
        print('Unable to insert into Hits')
        print(tab_dict)
    
    try:
        sql_chords = "insert into Chords (id, song, artist, tonality, capo, chords) VALUES('%d','%s','%s','%s','%d','%s')" % \
            (tab_dict['tab_id'], tab_dict['song_name'],
             tab_dict['artist'], tab_dict['tonality'],
             int(tab_dict['capo']),
             tab_dict['chords'])
        cur.execute(sql_chords)
        con.commit()
        
    except:
        print('Unable to insert into Chords')
        print(tab_dict)

    
def scrape_ultimate_guitar(url='https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords', pages=100):
    con, cur = create_sqlite_connector()
    
    print('Dropping sqlite tables')
    drop_tables_if_exists(con, cur)
    
    print('Creating sqlite tables')
    create_tables(con, cur) 

    print('Parsing pages')
    tabs_list, hits_list = get_multiple_pages('https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords', 100)    
    
    print('Parsing tabs for each page')
    for i in range(len(tabs_list)):
        print('Parsing tab #{}'.format(i))
        tab_dict = parse_tab_fields(tabs_list[i], hits_list[i])
        insert_data(tab_dict, con, cur)
        
    con.close()

# %%
scrape_ultimate_guitar()
# Out:
# Dropping sqlite tables
# Creating sqlite tables
# Parsing pages
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=1
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=2
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=3
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=4
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=5
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=6
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=7
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=8
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=9
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=10
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=11
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=12
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=13
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=14
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=15
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=16
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=17
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=18
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=19
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=20
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=21
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=22
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=23
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=24
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=25
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=26
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=27
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=28
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=29
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=30
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=31
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=32
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=33
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=34
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=35
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=36
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=37
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=38
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=39
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=40
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=41
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=42
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=43
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=44
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=45
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=46
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=47
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=48
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=49
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=50
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=51
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=52
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=53
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=54
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=55
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=56
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=57
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=58
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=59
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=60
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=61
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=62
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=63
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=64
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=65
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=66
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=67
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=68
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=69
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=70
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=71
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=72
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=73
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=74
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=75
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=76
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=77
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=78
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=79
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=80
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=81
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=82
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=83
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=84
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=85
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=86
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=87
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=88
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=89
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=90
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=91
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=92
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=93
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=94
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=95
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=96
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=97
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=98
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=99
# Succesfully loaded <div data-content>
# Attempting to reach link: https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=100
# Succesfully loaded <div data-content>
# Parsing tabs for each page
# Parsing tab #0
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/jeff-buckley/hallelujah-chords-198052
# Succesfully loaded <div data-content>
# Parsing tab #1
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ed-sheeran/perfect-chords-1956589
# Succesfully loaded <div data-content>
# Parsing tab #2
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/passenger/let-her-go-chords-1137467
# Succesfully loaded <div data-content>
# Parsing tab #3
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/john-legend/all-of-me-chords-1248578
# Succesfully loaded <div data-content>
# Parsing tab #4
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/elvis-presley/cant-help-falling-in-love-chords-1086983
# Succesfully loaded <div data-content>
# Parsing tab #5
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/jason-mraz/im-yours-chords-373896
# Succesfully loaded <div data-content>
# Parsing tab #6
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ed-sheeran/thinking-out-loud-chords-1486860
# Succesfully loaded <div data-content>
# Parsing tab #7
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/radiohead/creep-chords-4169
# Succesfully loaded <div data-content>
# Parsing tab #8
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/vance-joy/riptide-chords-1237247
# Succesfully loaded <div data-content>
# Parsing tab #9
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bruno-mars/when-i-was-your-man-chords-1198871
# Succesfully loaded <div data-content>
# Parsing tab #10
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ed-sheeran/photograph-chords-1493446
# Succesfully loaded <div data-content>
# Parsing tab #11
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/justin-bieber/love-yourself-chords-1780199
# Succesfully loaded <div data-content>
# Parsing tab #12
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/coldplay/the-scientist-chords-180849
# Succesfully loaded <div data-content>
# Parsing tab #13
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/pink-floyd/wish-you-were-here-chords-44555
# Succesfully loaded <div data-content>
# Parsing tab #14
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/adele/someone-like-you-chords-1006040
# Succesfully loaded <div data-content>
# Parsing tab #15
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/oasis/dont-look-back-in-anger-chords-6097
# Succesfully loaded <div data-content>
# Parsing tab #16
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/oasis/wonderwall-chords-39144
# Succesfully loaded <div data-content>
# Parsing tab #17
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/goo-goo-dolls/iris-chords-54512
# Succesfully loaded <div data-content>
# Parsing tab #18
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/taylor-swift/love-story-chords-730809
# Succesfully loaded <div data-content>
# Parsing tab #19
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/train/hey-soul-sister-chords-884388
# Succesfully loaded <div data-content>
# Parsing tab #20
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ed-sheeran/i-see-fire-chords-1430599
# Succesfully loaded <div data-content>
# Parsing tab #21
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/paramore/the-only-exception-chords-874862
# Succesfully loaded <div data-content>
# Parsing tab #22
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/coldplay/viva-la-vida-chords-675427
# Succesfully loaded <div data-content>
# Parsing tab #23
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/eagles/hotel-california-chords-46190
# Succesfully loaded <div data-content>
# Parsing tab #24
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/plain-white-ts/hey-there-delilah-chords-337676
# Succesfully loaded <div data-content>
# Parsing tab #25
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-beatles/let-it-be-chords-17427
# Succesfully loaded <div data-content>
# Parsing tab #26
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/oasis/wonderwall-chords-6125
# Succesfully loaded <div data-content>
# Parsing tab #27
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/extreme/more-than-words-chords-14087
# Succesfully loaded <div data-content>
# Parsing tab #28
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/kodaline/all-i-want-chords-1180259
# Succesfully loaded <div data-content>
# Parsing tab #29
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/imagine-dragons/radioactive-chords-1171909
# Succesfully loaded <div data-content>
# Parsing tab #30
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/green-day/boulevard-of-broken-dreams-chords-146744
# Succesfully loaded <div data-content>
# Parsing tab #31
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-animals/house-of-the-rising-sun-chords-18688
# Succesfully loaded <div data-content>
# Parsing tab #32
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-beatles/hey-jude-chords-17275
# Succesfully loaded <div data-content>
# Parsing tab #33
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/john-lennon/imagine-chords-9306
# Succesfully loaded <div data-content>
# Parsing tab #34
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/johnny-cash/hurt-chords-89849
# Succesfully loaded <div data-content>
# Parsing tab #35
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/sam-smith/stay-with-me-chords-1473600
# Succesfully loaded <div data-content>
# Parsing tab #36
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/oasis/wonderwall-chords-27596
# Succesfully loaded <div data-content>
# Parsing tab #37
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/misc-soundtrack/a-star-is-born-shallow-chords-2488086
# Succesfully loaded <div data-content>
# Parsing tab #38
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/jason-mraz/im-yours-chords-468625
# Succesfully loaded <div data-content>
# Parsing tab #39
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bruno-mars/just-the-way-you-are-chords-970416
# Succesfully loaded <div data-content>
# Parsing tab #40
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/adele/someone-like-you-chords-1006751
# Succesfully loaded <div data-content>
# Parsing tab #41
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/adele/rolling-in-the-deep-chords-1007655
# Succesfully loaded <div data-content>
# Parsing tab #42
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/onerepublic/counting-stars-chords-1233464
# Succesfully loaded <div data-content>
# Parsing tab #43
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/green-day/good-riddance-time-of-your-life-chords-12835
# Succesfully loaded <div data-content>
# Parsing tab #44
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-beatles/yesterday-chords-17450
# Succesfully loaded <div data-content>
# Parsing tab #45
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ed-sheeran/the-a-team-chords-989712
# Succesfully loaded <div data-content>
# Parsing tab #46
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/lewis-capaldi/someone-you-loved-chords-2512737
# Succesfully loaded <div data-content>
# Parsing tab #47
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/christina-perri/jar-of-hearts-chords-963934
# Succesfully loaded <div data-content>
# Parsing tab #48
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/john-denver/take-me-home-country-roads-chords-1101747
# Succesfully loaded <div data-content>
# Parsing tab #49
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/taylor-swift/you-belong-with-me-chords-752550
# Succesfully loaded <div data-content>
# Parsing tab #50
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/creedence-clearwater-revival/have-you-ever-seen-the-rain-chords-56479
# Succesfully loaded <div data-content>
# Parsing tab #51
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/adele/when-we-were-young-chords-1782038
# Succesfully loaded <div data-content>
# Parsing tab #52
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/coldplay/fix-you-chords-202594
# Succesfully loaded <div data-content>
# Parsing tab #53
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/frank-sinatra/fly-me-to-the-moon-chords-335196
# Succesfully loaded <div data-content>
# Parsing tab #54
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-cranberries/zombie-chords-844902
# Succesfully loaded <div data-content>
# Parsing tab #55
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/james-arthur/say-you-wont-let-go-chords-1874747
# Succesfully loaded <div data-content>
# Parsing tab #56
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/misc-soundtrack/a-star-is-born-shallow-chords-2480119
# Succesfully loaded <div data-content>
# Parsing tab #57
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/snow-patrol/chasing-cars-chords-355425
# Succesfully loaded <div data-content>
# Parsing tab #58
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bruno-mars/grenade-chords-993953
# Succesfully loaded <div data-content>
# Parsing tab #59
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-fray/how-to-save-a-life-chords-258804
# Succesfully loaded <div data-content>
# Parsing tab #60
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/misc-cartoons/frozen-let-it-go-chords-1445224
# Succesfully loaded <div data-content>
# Parsing tab #61
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/rihanna/stay-chords-1195964
# Succesfully loaded <div data-content>
# Parsing tab #62
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-script/breakeven-chords-733647
# Succesfully loaded <div data-content>
# Parsing tab #63
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/sam-smith/im-not-the-only-one-chords-1489018
# Succesfully loaded <div data-content>
# Parsing tab #64
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/don-mclean/american-pie-chords-187946
# Succesfully loaded <div data-content>
# Parsing tab #65
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/coldplay/yellow-chords-114080
# Succesfully loaded <div data-content>
# Parsing tab #66
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/adele/make-you-feel-my-love-chords-752102
# Succesfully loaded <div data-content>
# Parsing tab #67
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/a-great-big-world/say-something-chords-1429805
# Succesfully loaded <div data-content>
# Parsing tab #68
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/death-cab-for-cutie/i-will-follow-you-into-the-dark-chords-335735
# Succesfully loaded <div data-content>
# Parsing tab #69
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-script/the-man-who-cant-be-moved-chords-716149
# Succesfully loaded <div data-content>
# Parsing tab #70
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/james-blunt/youre-beautiful-chords-180394
# Succesfully loaded <div data-content>
# Parsing tab #71
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-lumineers/ho-hey-chords-1144876
# Succesfully loaded <div data-content>
# Parsing tab #72
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/jeff-buckley/hallelujah-chords-27336
# Succesfully loaded <div data-content>
# Parsing tab #73
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/pnk/just-give-me-a-reason-chords-1183088
# Succesfully loaded <div data-content>
# Parsing tab #74
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/4-non-blondes/whats-up-chords-349210
# Succesfully loaded <div data-content>
# Parsing tab #75
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bon-iver/skinny-love-chords-835053
# Succesfully loaded <div data-content>
# Parsing tab #76
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/foster-the-people/pumped-up-kicks-chords-1032143
# Succesfully loaded <div data-content>
# Parsing tab #77
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-neighbourhood/sweater-weather-chords-1237978
# Succesfully loaded <div data-content>
# Parsing tab #78
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bob-dylan/knockin-on-heavens-door-chords-66559
# Succesfully loaded <div data-content>
# Parsing tab #79
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/calum-scott/you-are-the-reason-chords-2267805
# Succesfully loaded <div data-content>
# Parsing tab #80
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/gotye/somebody-that-i-used-to-know-chords-1094597
# Succesfully loaded <div data-content>
# Parsing tab #81
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/dolly-parton/jolene-chords-183019
# Succesfully loaded <div data-content>
# Parsing tab #82
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/david-guetta/titanium-chords-1098920
# Succesfully loaded <div data-content>
# Parsing tab #83
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/mumford-sons/little-lion-man-chords-872773
# Succesfully loaded <div data-content>
# Parsing tab #84
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/guns-n-roses/sweet-child-o-mine-chords-176076
# Succesfully loaded <div data-content>
# Parsing tab #85
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/cat-stevens/father-and-son-chords-84491
# Succesfully loaded <div data-content>
# Parsing tab #86
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/green-day/21-guns-chords-823449
# Succesfully loaded <div data-content>
# Parsing tab #87
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/elton-john/your-song-chords-29113
# Succesfully loaded <div data-content>
# Parsing tab #88
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/radiohead/karma-police-chords-103398
# Succesfully loaded <div data-content>
# Parsing tab #89
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bob-marley/redemption-song-chords-417640
# Succesfully loaded <div data-content>
# Parsing tab #90
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ed-sheeran/shape-of-you-chords-1928439
# Succesfully loaded <div data-content>
# Parsing tab #91
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/kings-of-leon/use-somebody-chords-799959
# Succesfully loaded <div data-content>
# Parsing tab #92
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/shawn-mendes/stitches-chords-1721601
# Succesfully loaded <div data-content>
# Parsing tab #93
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/of-monsters-and-men/little-talks-chords-1046763
# Succesfully loaded <div data-content>
# Parsing tab #94
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/train/drops-of-jupiter-chords-1433
# Succesfully loaded <div data-content>
# Parsing tab #95
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-beatles/let-it-be-chords-60690
# Succesfully loaded <div data-content>
# Parsing tab #96
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/armada/harusnya-aku-chords-1733940
# Succesfully loaded <div data-content>
# Parsing tab #97
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/imagine-dragons/demons-chords-1148110
# Succesfully loaded <div data-content>
# Parsing tab #98
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/759809
# Succesfully loaded <div data-content>
# Parsing tab #99
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ben-e-king/stand-by-me-chords-73005
# Succesfully loaded <div data-content>
# Parsing tab #100
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/queen/bohemian-rhapsody-chords-1716013
# Succesfully loaded <div data-content>
# Parsing tab #101
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/secondhand-serenade/fall-for-you-chords-630290
# Succesfully loaded <div data-content>
# Parsing tab #102
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/avicii/wake-me-up-chords-1397194
# Succesfully loaded <div data-content>
# Parsing tab #103
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/fiersa-besari/waktu-yang-salah-chords-1693913
# Succesfully loaded <div data-content>
# Parsing tab #104
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/jeff-buckley/hallelujah-chords-328812
# Succesfully loaded <div data-content>
# Parsing tab #105
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-beatles/hey-jude-chords-1061739
# Succesfully loaded <div data-content>
# Parsing tab #106
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/john-denver/take-me-home-country-roads-chords-57606
# Succesfully loaded <div data-content>
# Parsing tab #107
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/jason-mraz/lucky-chords-681255
# Succesfully loaded <div data-content>
# Parsing tab #108
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/birdy/skinny-love-chords-1063670
# Succesfully loaded <div data-content>
# Parsing tab #109
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/queen/love-of-my-life-chords-340088
# Succesfully loaded <div data-content>
# Parsing tab #110
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/matt-redman/10000-reasons-bless-the-lord-chords-1076668
# Succesfully loaded <div data-content>
# Parsing tab #111
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bruno-mars/it-will-rain-chords-1096050
# Succesfully loaded <div data-content>
# Parsing tab #112
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/simon-garfunkel/the-sound-of-silence-chords-159157
# Succesfully loaded <div data-content>
# Parsing tab #113
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bryan-adams/heaven-chords-20606
# Succesfully loaded <div data-content>
# Parsing tab #114
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/david-guetta/titanium-chords-1085977
# Succesfully loaded <div data-content>
# Parsing tab #115
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/james-bay/let-it-go-chords-1680532
# Succesfully loaded <div data-content>
# Parsing tab #116
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/a-great-big-world/say-something-chords-1443639
# Succesfully loaded <div data-content>
# Parsing tab #117
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/gary-jules/mad-world-chords-97039
# Succesfully loaded <div data-content>
# Parsing tab #118
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/hozier/take-me-to-church-chords-1442757
# Succesfully loaded <div data-content>
# Parsing tab #119
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/r-e-m-/losing-my-religion-chords-114345
# Succesfully loaded <div data-content>
# Parsing tab #120
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ed-sheeran/the-a-team-chords-1196902
# Succesfully loaded <div data-content>
# Parsing tab #121
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/hillsong-united/oceans-where-feet-may-fail-chords-1218238
# Succesfully loaded <div data-content>
# Parsing tab #122
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/tracy-chapman/fast-car-chords-1044807
# Succesfully loaded <div data-content>
# Parsing tab #123
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/old-crow-medicine-show/wagon-wheel-chords-754823
# Succesfully loaded <div data-content>
# Parsing tab #124
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/magic/rude-chords-1445813
# Succesfully loaded <div data-content>
# Parsing tab #125
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/avenged-sevenfold/so-far-away-chords-972646
# Succesfully loaded <div data-content>
# Parsing tab #126
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bruno-mars/talking-to-the-moon-chords-971346
# Succesfully loaded <div data-content>
# Parsing tab #127
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/sixpence-none-the-richer/kiss-me-chords-2707
# Succesfully loaded <div data-content>
# Parsing tab #128
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/nirvana/smells-like-teen-spirit-chords-807883
# Succesfully loaded <div data-content>
# Parsing tab #129
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/oasis/wonderwall-chords-165916
# Succesfully loaded <div data-content>
# Parsing tab #130
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/lukas-graham/7-years-chords-1752864
# Succesfully loaded <div data-content>
# Parsing tab #131
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bill-withers/aint-no-sunshine-chords-468744
# Succesfully loaded <div data-content>
# Parsing tab #132
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/david-bowie/space-oddity-chords-105869
# Succesfully loaded <div data-content>
# Parsing tab #133
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/red-hot-chili-peppers/californication-chords-202765
# Succesfully loaded <div data-content>
# Parsing tab #134
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/pixies/where-is-my-mind-chords-89446
# Succesfully loaded <div data-content>
# Parsing tab #135
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/taylor-swift/teardrops-on-my-guitar-chords-429289
# Succesfully loaded <div data-content>
# Parsing tab #136
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/aerosmith/i-dont-want-to-miss-a-thing-chords-59465
# Succesfully loaded <div data-content>
# Parsing tab #137
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/one-direction/little-things-chords-1191790
# Succesfully loaded <div data-content>
# Parsing tab #138
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/anji/menunggu-kamu-chords-2333561
# Succesfully loaded <div data-content>
# Parsing tab #139
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bright-eyes/first-day-of-my-life-chords-154240
# Succesfully loaded <div data-content>
# Parsing tab #140
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/queen/bohemian-rhapsody-chords-40606
# Succesfully loaded <div data-content>
# Parsing tab #141
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/sia/chandelier-chords-1476462
# Succesfully loaded <div data-content>
# Parsing tab #142
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/sam-smith/too-good-at-goodbyes-chords-2142281
# Succesfully loaded <div data-content>
# Parsing tab #143
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/train/hey-soul-sister-chords-868189
# Succesfully loaded <div data-content>
# Parsing tab #144
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ed-sheeran/thinking-out-loud-chords-1486901
# Succesfully loaded <div data-content>
# Parsing tab #145
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/taylor-swift/safe-and-sound-chords-1118992
# Succesfully loaded <div data-content>
# Parsing tab #146
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/linkin-park/numb-chords-90873
# Succesfully loaded <div data-content>
# Parsing tab #147
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/john-legend/all-of-me-chords-1432996
# Succesfully loaded <div data-content>
# Parsing tab #148
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/eric-clapton/tears-in-heaven-chords-627220
# Succesfully loaded <div data-content>
# Parsing tab #149
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/johnny-cash/ring-of-fire-chords-63352
# Succesfully loaded <div data-content>
# Parsing tab #150
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/christina-perri/a-thousand-years-chords-1101795
# Succesfully loaded <div data-content>
# Parsing tab #151
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/taylor-swift/i-knew-you-were-trouble-chords-1187569
# Succesfully loaded <div data-content>
# Parsing tab #152
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/chris-isaak/wicked-game-chords-11066
# Succesfully loaded <div data-content>
# Parsing tab #153
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/taylor-swift/blank-space-chords-1674053
# Succesfully loaded <div data-content>
# Parsing tab #154
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/justin-bieber/baby-chords-911859
# Succesfully loaded <div data-content>
# Parsing tab #155
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/coldplay/fix-you-chords-1863305
# Succesfully loaded <div data-content>
# Parsing tab #156
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bastille/pompeii-chords-1227805
# Succesfully loaded <div data-content>
# Parsing tab #157
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/metallica/nothing-else-matters-chords-8802
# Succesfully loaded <div data-content>
# Parsing tab #158
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/adam-levine/lost-stars-chords-1496532
# Succesfully loaded <div data-content>
# Parsing tab #159
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/lady-a-lady-antebellum/need-you-now-chords-866111
# Succesfully loaded <div data-content>
# Parsing tab #160
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/joseph-vincent/cant-take-my-eyes-off-you-chords-1883548
# Succesfully loaded <div data-content>
# Parsing tab #161
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/daniel-caesar/best-part-chords-2126075
# Succesfully loaded <div data-content>
# Parsing tab #162
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/camila-cabello/havana-chords-2105155
# Succesfully loaded <div data-content>
# Parsing tab #163
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/misc-soundtrack/a-star-is-born-always-remember-us-this-way-chords-2484211
# Succesfully loaded <div data-content>
# Parsing tab #164
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/journey/dont-stop-believin-chords-275297
# Succesfully loaded <div data-content>
# Parsing tab #165
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ed-sheeran/happier-chords-1956585
# Succesfully loaded <div data-content>
# Parsing tab #166
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/jason-mraz/im-yours-chords-499752
# Succesfully loaded <div data-content>
# Parsing tab #167
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bruno-mars/the-lazy-song-chords-992284
# Succesfully loaded <div data-content>
# Parsing tab #168
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bob-marley/three-little-birds-chords-166605
# Succesfully loaded <div data-content>
# Parsing tab #169
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ed-sheeran/give-me-love-chords-1154540
# Succesfully loaded <div data-content>
# Parsing tab #170
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ed-sheeran/photograph-chords-1495700
# Succesfully loaded <div data-content>
# Parsing tab #171
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/america/a-horse-with-no-name-chords-59609
# Succesfully loaded <div data-content>
# Parsing tab #172
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/wham/last-christmas-chords-169565
# Succesfully loaded <div data-content>
# Parsing tab #173
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/lifehouse/you-and-me-chords-162344
# Succesfully loaded <div data-content>
# Parsing tab #174
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bruno-mars/the-lazy-song-chords-999755
# Succesfully loaded <div data-content>
# Parsing tab #175
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/calum-scott/dancing-on-my-own-chords-1835574
# Succesfully loaded <div data-content>
# Parsing tab #176
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/u2/with-or-without-you-chords-835
# Succesfully loaded <div data-content>
# Parsing tab #177
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bruno-mars/count-on-me-chords-958496
# Succesfully loaded <div data-content>
# Parsing tab #178
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/one-direction/night-changes-chords-1678440
# Succesfully loaded <div data-content>
# Parsing tab #179
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/eagles/take-it-easy-chords-14322
# Succesfully loaded <div data-content>
# Parsing tab #180
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/death-cab-for-cutie/i-will-follow-you-into-the-dark-chords-204631
# Succesfully loaded <div data-content>
# Parsing tab #181
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ed-sheeran/castle-on-the-hill-chords-1928433
# Succesfully loaded <div data-content>
# Parsing tab #182
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/meghan-trainor/like-im-gonna-lose-you-chords-1715372
# Succesfully loaded <div data-content>
# Parsing tab #183
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/maroon-5/payphone-chords-1147850
# Succesfully loaded <div data-content>
# Parsing tab #184
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/misc-christmas/jingle-bells-chords-273336
# Succesfully loaded <div data-content>
# Parsing tab #185
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/labrinth/jealous-chords-1696042
# Succesfully loaded <div data-content>
# Parsing tab #186
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/taylor-swift/everything-has-changed-chords-1189502
# Succesfully loaded <div data-content>
# Parsing tab #187
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/adele/rolling-in-the-deep-chords-1028320
# Succesfully loaded <div data-content>
# Parsing tab #188
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/mumford-sons/i-will-wait-chords-1174384
# Succesfully loaded <div data-content>
# Parsing tab #189
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/taylor-swift/back-to-december-chords-995170
# Succesfully loaded <div data-content>
# Parsing tab #190
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ed-sheeran/lego-house-chords-1093774
# Succesfully loaded <div data-content>
# Parsing tab #191
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-beatles/across-the-universe-chords-202167
# Succesfully loaded <div data-content>
# Parsing tab #192
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/charlie-puth/one-call-away-chords-1761302
# Succesfully loaded <div data-content>
# Parsing tab #193
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/carly-rae-jepsen/call-me-maybe-chords-1120096
# Succesfully loaded <div data-content>
# Parsing tab #194
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/judy-garland/have-yourself-a-merry-little-christmas-chords-762486
# Succesfully loaded <div data-content>
# Parsing tab #195
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/darius-rucker/wagon-wheel-chords-1215756
# Succesfully loaded <div data-content>
# Parsing tab #196
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/john-denver/leaving-on-a-jet-plane-chords-32979
# Succesfully loaded <div data-content>
# Parsing tab #197
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/creedence-clearwater-revival/bad-moon-rising-chords-15892
# Succesfully loaded <div data-content>
# Parsing tab #198
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/nirvana/where-did-you-sleep-last-night-chords-47489
# Succesfully loaded <div data-content>
# Parsing tab #199
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/leonard-cohen/hallelujah-chords-64977
# Succesfully loaded <div data-content>
# Parsing tab #200
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-killers/mr-brightside-chords-202646
# Succesfully loaded <div data-content>
# Parsing tab #201
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/156298
# Succesfully loaded <div data-content>
# Parsing tab #202
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/poison/every-rose-has-its-thorn-chords-130272
# Succesfully loaded <div data-content>
# Parsing tab #203
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/chris-tomlin/how-great-is-our-god-chords-166109
# Succesfully loaded <div data-content>
# Parsing tab #204
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/natalie-imbruglia/torn-chords-11489
# Succesfully loaded <div data-content>
# Parsing tab #205
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/passenger/let-her-go-chords-1196760
# Succesfully loaded <div data-content>
# Parsing tab #206
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/billie-eilish/ocean-eyes-chords-1834352
# Succesfully loaded <div data-content>
# Parsing tab #207
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/luis-fonsi/despacito-chords-1932541
# Succesfully loaded <div data-content>
# Parsing tab #208
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/adele/all-i-ask-chords-1782459
# Succesfully loaded <div data-content>
# Parsing tab #209
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/parokya-ni-edgar/harana-chords-79821
# Succesfully loaded <div data-content>
# ...
# Succesfully loaded <div data-content>
# Parsing tab #3498
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/1177119
# Succesfully loaded <div data-content>
# Parsing tab #3499
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/damien-rice/cannonball-chords-432877
# Succesfully loaded <div data-content>
# Parsing tab #3500
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/josh-groban/you-raise-me-up-chords-261760
# Succesfully loaded <div data-content>
# Parsing tab #3501
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-beatles/honey-pie-chords-1061750
# Succesfully loaded <div data-content>
# Parsing tab #3502
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/mymp/tell-me-where-it-hurts-chords-182767
# Succesfully loaded <div data-content>
# Parsing tab #3503
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/misc-cartoons/adventure-time-im-just-your-problem-chords-1096759
# Succesfully loaded <div data-content>
# Parsing tab #3504
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-beatles/two-of-us-chords-1099477
# Succesfully loaded <div data-content>
# Parsing tab #3505
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bon-jovi/you-give-love-a-bad-name-chords-1242523
# Succesfully loaded <div data-content>
# Parsing tab #3506
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/matt-corby/brother-chords-1117949
# Succesfully loaded <div data-content>
# Parsing tab #3507
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/cat-stevens/the-first-cut-is-the-deepest-chords-393971
# Succesfully loaded <div data-content>
# Parsing tab #3508
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bruce-springsteen/born-in-the-usa-chords-148158
# Succesfully loaded <div data-content>
# Parsing tab #3509
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/robbie-williams/angels-chords-704443
# Succesfully loaded <div data-content>
# Parsing tab #3510
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/audrey-hepburn/moon-river-chords-1480951
# Succesfully loaded <div data-content>
# Parsing tab #3511
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/arctic-monkeys/crying-lightning-chords-875366
# Succesfully loaded <div data-content>
# Parsing tab #3512
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/muse/hysteria-chords-117949
# Succesfully loaded <div data-content>
# Parsing tab #3513
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/elton-john/tiny-dancer-chords-900075
# Succesfully loaded <div data-content>
# Parsing tab #3514
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/payung-teduh/resah-chords-1492244
# Succesfully loaded <div data-content>
# Parsing tab #3515
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/paramore/last-hope-chords-1235239
# Succesfully loaded <div data-content>
# Parsing tab #3516
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/r-e-m-/losing-my-religion-chords-338351
# Succesfully loaded <div data-content>
# Parsing tab #3517
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/jesus-culture/let-it-rain-chords-1023872
# Succesfully loaded <div data-content>
# Parsing tab #3518
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/naughty-boy/runnin-lose-it-all-chords-1768423
# Succesfully loaded <div data-content>
# Parsing tab #3519
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/celine-dion/because-you-loved-me-chords-706787
# Succesfully loaded <div data-content>
# Parsing tab #3520
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/seiler-und-speer/ham-kummst-chords-1697589
# Succesfully loaded <div data-content>
# Parsing tab #3521
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-doors/love-me-two-times-chords-15027
# Succesfully loaded <div data-content>
# Parsing tab #3522
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/shocking-blue/venus-chords-84823
# Succesfully loaded <div data-content>
# Parsing tab #3523
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/train/hey-soul-sister-chords-937879
# Succesfully loaded <div data-content>
# Parsing tab #3524
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/cake/i-will-survive-chords-689767
# Succesfully loaded <div data-content>
# Parsing tab #3525
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/yovie-nuno/janji-suci-chords-1424363
# Succesfully loaded <div data-content>
# Parsing tab #3526
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/lady-a-lady-antebellum/just-a-kiss-chords-1056291
# Succesfully loaded <div data-content>
# Parsing tab #3527
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bee-gees/to-love-somebody-chords-1088898
# Succesfully loaded <div data-content>
# Parsing tab #3528
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/neck-deep/wish-you-were-here-chords-2116383
# Succesfully loaded <div data-content>
# Parsing tab #3529
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bread/everything-i-own-chords-1044786
# Succesfully loaded <div data-content>
# Parsing tab #3530
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/alice-in-chains/down-in-a-hole-chords-969470
# Succesfully loaded <div data-content>
# Parsing tab #3531
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ed-sheeran/i-see-fire-chords-1430097
# Succesfully loaded <div data-content>
# Parsing tab #3532
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/tracy-chapman/talkin-bout-a-revolution-chords-594154
# Succesfully loaded <div data-content>
# Parsing tab #3533
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/coldplay/warning-sign-chords-268630
# Succesfully loaded <div data-content>
# Parsing tab #3534
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/band-of-horses/the-funeral-chords-644891
# Succesfully loaded <div data-content>
# Parsing tab #3535
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/oasis/let-there-be-love-chords-179820
# Succesfully loaded <div data-content>
# Parsing tab #3536
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/one-direction/little-things-chords-1191891
# Succesfully loaded <div data-content>
# Parsing tab #3537
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/jose-mari-chan/christmas-in-our-hearts-chords-64587
# Succesfully loaded <div data-content>
# Parsing tab #3538
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/mumford-sons/the-boxer-chords-1184953
# Succesfully loaded <div data-content>
# Parsing tab #3539
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/amy-macdonald/this-is-the-life-chords-609531
# Succesfully loaded <div data-content>
# Parsing tab #3540
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/rod-stewart/sailing-chords-380559
# Succesfully loaded <div data-content>
# Parsing tab #3541
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/alice-in-chains/rooster-chords-863637
# Succesfully loaded <div data-content>
# Parsing tab #3542
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/xxxtentacion/depression-and-obsession-chords-2123801
# Succesfully loaded <div data-content>
# Parsing tab #3543
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-proclaimers/im-gonna-be-500-miles-chords-437547
# Succesfully loaded <div data-content>
# Parsing tab #3544
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/thin-lizzy/whiskey-in-the-jar-chords-519801
# Succesfully loaded <div data-content>
# Parsing tab #3545
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/luke-combs/when-it-rains-it-pours-chords-1935041
# Succesfully loaded <div data-content>
# Parsing tab #3546
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/922412
# Succesfully loaded <div data-content>
# Parsing tab #3547
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/justin-bieber/be-alright-chords-1119795
# Succesfully loaded <div data-content>
# Parsing tab #3548
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/ariana-grande/no-tears-left-to-cry-chords-2371739
# Succesfully loaded <div data-content>
# Parsing tab #3549
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/dmasiv/merindukanmu-chords-850728
# Succesfully loaded <div data-content>
# Parsing tab #3550
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/labrinth/beneath-your-beautiful-chords-1192658
# Succesfully loaded <div data-content>
# Parsing tab #3551
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/sugarland/stuck-like-glue-chords-972409
# Succesfully loaded <div data-content>
# Parsing tab #3552
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/robin-thicke/blurred-lines-chords-1248268
# Succesfully loaded <div data-content>
# Parsing tab #3553
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/david-guetta/without-you-chords-1099262
# Succesfully loaded <div data-content>
# Parsing tab #3554
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-beatles/in-my-life-chords-89344
# Succesfully loaded <div data-content>
# Parsing tab #3555
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/paul-mccartney/band-on-the-run-chords-75224
# Succesfully loaded <div data-content>
# Parsing tab #3556
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/silbermond/das-beste-chords-421086
# Succesfully loaded <div data-content>
# Parsing tab #3557
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-beatles/something-chords-17436
# Succesfully loaded <div data-content>
# Parsing tab #3558
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/procol-harum/a-whiter-shade-of-pale-chords-958255
# Succesfully loaded <div data-content>
# Parsing tab #3559
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/post-malone/stay-chords-2376541
# Succesfully loaded <div data-content>
# Parsing tab #3560
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/maximillian-denmark/beautiful-scars-chords-3020456
# Succesfully loaded <div data-content>
# Parsing tab #3561
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/coldplay/speed-of-sound-chords-183975
# Succesfully loaded <div data-content>
# Parsing tab #3562
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/luke-bryan/play-it-again-chords-1413721
# Succesfully loaded <div data-content>
# Parsing tab #3563
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/mumford-sons/below-my-feet-chords-1035441
# Succesfully loaded <div data-content>
# Parsing tab #3564
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/justin-bieber/baby-chords-915337
# Succesfully loaded <div data-content>
# Parsing tab #3565
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/two-door-cinema-club/what-you-know-chords-946263
# Succesfully loaded <div data-content>
# Parsing tab #3566
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/jason-derulo/want-to-want-me-chords-1722046
# Succesfully loaded <div data-content>
# Parsing tab #3567
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/misc-traditional/greensleeves-chords-173713
# Succesfully loaded <div data-content>
# Parsing tab #3568
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/chris-tomlin/at-the-cross-love-ran-red-chords-1463998
# Succesfully loaded <div data-content>
# Parsing tab #3569
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/angus-julia-stone/just-a-boy-chords-596623
# Succesfully loaded <div data-content>
# Parsing tab #3570
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/olivia-rodrigo/enough-for-you-chords-3716339
# Succesfully loaded <div data-content>
# Parsing tab #3571
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/basil-valdez/you-chords-569527
# Succesfully loaded <div data-content>
# Parsing tab #3572
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-beatles/real-love-chords-322550
# Succesfully loaded <div data-content>
# Parsing tab #3573
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/aj-rafael/she-was-mine-chords-978128
# Succesfully loaded <div data-content>
# Parsing tab #3574
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/florence-the-machine/cosmic-love-chords-980714
# Succesfully loaded <div data-content>
# Parsing tab #3575
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/taylor-swift/a-place-in-this-world-chords-429292
# Succesfully loaded <div data-content>
# Parsing tab #3576
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/kim-walker-smith/i-need-you-more-chords-1211022
# Succesfully loaded <div data-content>
# Parsing tab #3577
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/daniel-padilla/simpleng-tulad-mo-chords-1507681
# Succesfully loaded <div data-content>
# Parsing tab #3578
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/sara-evans/born-to-fly-chords-199272
# Succesfully loaded <div data-content>
# Parsing tab #3579
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-smashing-pumpkins/tonight-tonight-chords-771138
# Succesfully loaded <div data-content>
# Parsing tab #3580
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/neck-deep/a-part-of-me-chords-1201137
# Succesfully loaded <div data-content>
# Parsing tab #3581
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/1018404
# Succesfully loaded <div data-content>
# Parsing tab #3582
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/porcupine-tree/trains-chords-576064
# Succesfully loaded <div data-content>
# Parsing tab #3583
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/crosby-stills-nash/helplessly-hoping-chords-64116
# Succesfully loaded <div data-content>
# Parsing tab #3584
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/coldplay/the-scientist-chords-63759
# Succesfully loaded <div data-content>
# Parsing tab #3585
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-rolling-stones/brown-sugar-chords-604358
# Succesfully loaded <div data-content>
# Parsing tab #3586
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/fetty-wap/trap-queen-chords-1723877
# Succesfully loaded <div data-content>
# Parsing tab #3587
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/knaan/wavin-flag-chords-798536
# Succesfully loaded <div data-content>
# Parsing tab #3588
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/lilly-wood-the-prick/prayer-in-c-chords-1492938
# Succesfully loaded <div data-content>
# Parsing tab #3589
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/1690369
# Succesfully loaded <div data-content>
# Parsing tab #3590
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/faber-drive/tongue-tied-chords-531348
# Succesfully loaded <div data-content>
# Parsing tab #3591
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/bon-jovi/livin-on-a-prayer-chords-1185747
# Succesfully loaded <div data-content>
# Parsing tab #3592
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/frank-sinatra/my-funny-valentine-chords-271557
# Succesfully loaded <div data-content>
# Parsing tab #3593
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/elvis-presley/blue-christmas-chords-1443011
# Succesfully loaded <div data-content>
# Parsing tab #3594
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/misc-cartoons/lava-lava-chords-1746393
# Succesfully loaded <div data-content>
# Parsing tab #3595
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-beatles/i-want-to-hold-your-hand-chords-513756
# Succesfully loaded <div data-content>
# Parsing tab #3596
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/kings-of-leon/closer-chords-739218
# Succesfully loaded <div data-content>
# Parsing tab #3597
# Attempting to reach link: https://tabs.ultimate-guitar.com/tab/the-police/every-breath-you-take-chords-327965

# %%
# Out:
# <Response [200]>

# %%
from requests import get

try:
    with closing(get('https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=1', stream=True)) as resp:
        print('res', resp)
        if is_good_response(resp):
            console.log('url:', url, resp.content)
            return resp.content
        else:
            return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None
# Out:
#   File "<ipython-input-21-f5b91b152659>", line 12
#     except RequestException as e:
#     ^
# SyntaxError: invalid syntax

# %%
import sqlite3
import re
import json
import pandas as pd
import time
from bs4 import BeautifulSoup
from requests import get
from requests.exceptions import RequestException
from contextlib import closing



def is_good_response(resp):
    """
    Source: https://realpython.com/python-web-scraping-practical-introduction/
    Returns true if the response seems to be HTML, false otherwise
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)

try:
    with closing(get('https://www.ultimate-guitar.com/explore?order=hitstotal_desc&type[]=Chords&page=1', stream=True)) as resp:
        
        print(is_good_response(resp))

except RequestException as e:
    log_error('Error during requests to {0} : {1}'.format(url, str(e)))
# Out:
# True
